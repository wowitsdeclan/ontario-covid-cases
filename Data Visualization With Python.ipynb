# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
x = [1, 2, 3]
y = [1, 4, 9]
z = [10, 5, 0]
plt.plot(x, y)
plt.plot(x, z)
plt.title("test Plot")
plt.xlabel('X')
plt.ylabel('Y and Z')
plt.legend(["this is y", "This is z"])
plt.show()

# %%
sample_data = pd.read_csv('sample_data.csv')

# %%
sample_data
# Out:
#    column_a  column_b  column_c
# 0         1         1        10
# 1         2         4         8
# 2         3         9         6
# 3         4        16         4
# 4         5        25         2

# %%
type(sample_data.column_c)
# Out:
# pandas.core.series.Series

# %%
sample_data.column_c.iloc[0]
# Out:
# 10

# %%
plt.plot(sample_data.column_a, sample_data.column_b, 'o')
plt.plot(sample_data.column_a, sample_data.column_c)
plt.show()

# %%
data= pd.read_csv('countries.csv')

# %%
data
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
us = data[data.country == 'United States']

# %%
us
# Out:
#             country  year  population
# 1608  United States  1952   157553000
# 1609  United States  1957   171984000
# 1610  United States  1962   186538000
# 1611  United States  1967   198712000
# 1612  United States  1972   209896000
# 1613  United States  1977   220239000
# 1614  United States  1982   232187835
# 1615  United States  1987   242803533
# 1616  United States  1992   256894189
# 1617  United States  1997   272911760
# 1618  United States  2002   287675526
# 1619  United States  2007   301139947

# %%
china = data[data.country == 'China']

# %%
plt.plot(us.year, us.population / 10**6)
plt.plot(china.year, china.population / 10**6)
plt.xlabel('Year')
plt.ylabel('Population in millions')
plt.legend(["China", "USA"])
plt.show()

# %%
us.population
# Out:
# 1608    157553000
# 1609    171984000
# 1610    186538000
# 1611    198712000
# 1612    209896000
# 1613    220239000
# 1614    232187835
# 1615    242803533
# 1616    256894189
# 1617    272911760
# 1618    287675526
# 1619    301139947
# Name: population, dtype: int64

# %%
us.population / us.population.iloc[0] * 100
# Out:
# 1608    100.000000
# 1609    109.159457
# 1610    118.396984
# 1611    126.123908
# 1612    133.222471
# 1613    139.787246
# 1614    147.371256
# 1615    154.109114
# 1616    163.052553
# 1617    173.219018
# 1618    182.589685
# 1619    191.135648
# Name: population, dtype: float64

# %%
plt.plot(us.year, us.population / us.population.iloc[0] * 100)
plt.plot(china.year, china.population / china.population.iloc[0] * 100)
plt.xlabel('Year')
plt.ylabel('Population in millions')
plt.legend(["China", "USA"])
plt.show()

# %%
cases = pd.read_csv('canada-covid-cases.csv')

# %%
cases
# Out:
#       pruid                  prname                   prnameFR        date  \
# 0        35                 Ontario                    Ontario  2020-01-31
# 1        59        British Columbia       Colombie-Britannique  2020-01-31
# 2         1                  Canada                     Canada  2020-01-31
# 3        35                 Ontario                    Ontario  2020-02-08
# 4        59        British Columbia       Colombie-Britannique  2020-02-08
# ...     ...                     ...                        ...         ...
# 6352     60                   Yukon                      Yukon  2021-05-04
# 6353     61   Northwest Territories  Territoires du Nord-Ouest  2021-05-04
# 6354     62                 Nunavut                    Nunavut  2021-05-04
# 6355     99  Repatriated travellers        Voyageurs rapatriés  2021-05-04
# 6356      1                  Canada                     Canada  2021-05-04
#
# ...

# %%
ontario = cases[cases.prname == 'Ontario']

# %%
ontario
# Out:
#       pruid   prname prnameFR        date  update  numconf  numprob  \
# 0        35  Ontario  Ontario  2020-01-31     NaN        3      0.0
# 3        35  Ontario  Ontario  2020-02-08     NaN        3      0.0
# 6        35  Ontario  Ontario  2020-02-16     NaN        3      0.0
# 9        35  Ontario  Ontario  2020-02-21     NaN        3      0.0
# 12       35  Ontario  Ontario  2020-02-24     NaN        4      0.0
# ...     ...      ...      ...         ...     ...      ...      ...
# 6286     35  Ontario  Ontario  2021-04-30     1.0   463364      0.0
# 6301     35  Ontario  Ontario  2021-05-01     1.0   466733      0.0
# 6316     35  Ontario  Ontario  2021-05-02     1.0   470465      NaN
# 6331     35  Ontario  Ontario  2021-05-03     1.0   473901      NaN
# 6346     35  Ontario  Ontario  2021-05-04     1.0   476692      NaN
#
#       numdeaths  numtotal  numtested  ...  ratedeaths_last14  numtotal_last7  \
# ...

# %%
plt.plot(ontario.date, ontario.numconf)
plt.plot(ontario.date, ontario.numdeaths)
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.legend(["Total Case", "Deaths"])
plt.show()
